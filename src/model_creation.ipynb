# %% [markdown]
# ### Introduction
# I'll build a recommender system using a modified version of Word2Vec, named Item2Vec ([1]), which consists in a collaborative filtering algorithm that aplies Word2Vec's Skip-Gram architecture on a non-natural language dataset.
#
# Word2Vec is a 1 hidden layer fully connected neural network that learns vector embeddings of words in a latent space. These embeddings are able to preserve word semantincs based on the their context (defined by a window size). Words that appear in similar contexts will tend to have similar vector representations.
# Word2Vec comes with 2 architecture options:
# 1. Continuous bag of words (CBOW): tries to predict a word based on its context.
# 2. Skip Gram (SG): tries to predict the context of a word that is given as an input.
#
# Since Item2Vec uses Skip-Gram, I'll only focus on its presentation.
#
# The image below ([4]) shows the neural network architecture.
# ![skip_gram_image_placeholder](./../images/skip_gram_net_arch.png)
#
# The input layer has the size of the vocabulary (10000 in the example above) and receives the one-hot vector representation of the word used for prediction.
#
# The hidden layer size is equal to the dimension of learnt vector embeddings (300 in the example above) and represents a hyperparameter. The weight matrix will have 300 columns (the number of features) and 10000 rows (one for word in the vocabulary).
#
# The output layer gives a probability distribution that will tell for each word in the vocabulary the probability of it being part of the input word's context.
#
# There are some additional techniques that the authors of Word2Vec proposed in their second paper ([5]) in order to optimize the training of the neural network.
#
# **Subsampling**\
# It is used to decrease the number of training examples by removing the words that appear most frequently. Usually, these are stop words that do not have relevant semantic meaning, since they appear in all sorts of contexts. The probability of a word being removed is given by the following formula
#
# ![subsampling_image_placeholder](./../images/subsampling.png)
#
# where f(w) represents the frequency of the given word in the vocabulary and t is a hyperparameter threshold usually chosen around 10<sup>-5</sup>.
#
# **Negative sampling**
# The training of this network will require a lot of time, since it implies the updating of the weight matrix which for a vocabulary of 10000 words and a hidden layer of 300 neurons will have **3 millions** weights. That's why a new technique called negative sampling has been introduced. This optimization implies modifing a very small sample of weights:
# - the weight of the correct output neuron, so that it will result in a high probability of being part of the input word's context
# - select a few (5-20) words from the vocabulary that will be treated as negative examples; Their weight will be updated so that their probability of being part of the input word's context will be decreased; For small vocabularies 5-20 negative samples are needed, whereas for larger vocabularies 2-5 samples are sufficient.
# The probability of a word being picked as a negative example is given by the following formula
#
# ![negative_sampling_image_placeholder](./../images/negative_sampling.png)
#
# where f(w) represents the frequency of the given word in the vocabulary. Therefore, most frequent words will have a higher probabily of being picked as negative examples.
#
#
# **Item2Vec** aims to apply Word2Vec's Skip-Gram with negative sampling architecture on various sequences of objects belonging to non-linguistic datasets. Item2Vec can be applied to movie reviews lists, shopping cart items, lists of appreciated songs etc. in order to build a recommender system that is based on calculating the similarities of items that the user enjoys. Another characteristic of Item2Vec is that the window size is considered infinite because all the items in a given sequence of objects are considered to be part of the same context.
#
# In this script I'll train this model on Movielens 1M, a dataset of 1 million movie reviews ([6]) received from ~6000 users on a total of 3883 movies.
#
# The data has been explored and cleaned in separate scripts of this project. Check `data/initial_exploration` notebook and `data/make_dataset.py`.

# %%
import pandas as pd;
import numpy as np;
import logging

from random import shuffle
from sklearn.model_selection import KFold
from gensim.models import Word2Vec
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# Both training and testing entries are grouped by userId. Doing so, I can extract a list of movies that were rated by a specific user. After that, I split each list of movies into 'liked' and 'disliked' sublists. The first one contains all the movies that the user has rated with >=3 stars, whereas the second list contains all the movies that got a review of 1 or 2 stars. These lists of movie ids will consist in so-called 'sentences' that will be later used in training the **Word2Vec** model. The movie ids will represent the 'words' in our context.
#
# The **Word2Vec** model that I'm going to train will try to learn the embeddings of the movie ids in a latent space so that similar movies (movies that appear together in the liked/disliked sublists) will have close vector representations. The distance between movies' embeddings (learned by the model) that usually belong to the same sentences should be small, whereas the distance between movies that belong to different lists (one belongs to a user's liked list and the other belongs to the same user's disliked list) should be large.

# %% [markdown]
# Word2Vec hyperparameters were picked taking into account various values used in literature and based on personal experiments.
#
# | Parameter name | Description | Value | Comments on the chosen values |
# | --- | ----------- | ------- | ----- |
# | size | Size of hidden layer (dimension of learned vectors) | 64 | Multiple of 4 is chosen for greater performance (according to gensim documentation). Increasing the embedding size didn't have a major impact on the F1 score. |
# | window | The size of window defining the context of the word | 999 | A big value, so all the movies in a user's liked or disliked list define the context used in learning |
# | min_count | Minimum number of appearances for a word to be kept in the vocabulary | 5 | A movie should appear at least 4 times in the whole corpus in order to be kept in the vocabulary |
# | iter | Number of epochs | 30 | Tried: [5, 10, 15, 20, 25, **30**, 35]. Highest score reached at 30 |
# | sg | 1 for Skip-Gram strategy, 0 for CBOW | 1 | Skip-Gram technique works best for Item2Vec. According to Mikolov, Skip-Gram is a good solution for small datasets and is able to create a good represenation for rare words.|
# | hs | 1 for hierarchical softmax, 0 and and negative > 0 for use of negative sampling | 0 | Chose 0 because applying negative-sampling gives better results |
# | sample | a threshold used for configuring the number of most popular words that are removed from the vocabulary | 5e-4 | Tried [e-4, **5e-4**, e-5].  |
# | negative | how many random words are marked as negative examples | 30 | Tried: [5, 10, 20, **30**, 35]. Because the dataset is small, a higher value was needed.  |
#
# After training the model, I evaluate it the following manner:
#
# For each user in the testing set extract the user's list of liked movies (from the test data) and try to predict them. There are several ways of doing this predictions. First of all, you can use only the list of movies that the user liked in the training set or use both the liked and disliked lists. I tried both methods and it looks like the solution that uses the disliked lists brings a small improvement in the overall F1 score.
#
# The number of predictions also impacts the overall results. I did 3 sets of predictions. Basically, I predicted a list of movies that has the length of test_liked_list_length * K, where K=1,2,3.
#
# Three evaluation metrics were used:
# - Precision: the ratio between the number of correctly predicted movies and the total number of predictions; it decreases as the number of predictions increases, i.e. as K increases
# - Recall: the ratio between the number of correctly predicted movies and the total number of liked movies in the test set; it increases as the number of predictions increases
# - F1-score: the harmonic mean of precision and recall; Achived best results for K = 2
#
#
# 5-Folds Cross-validation has been used to compute the mean score of the model. The following scores have been obtained:
# <table>
#     <thead>
#         <tr>
#           <th></th>
#             <th colspan="3">Using only positive examples</th>
#             <th colspan="3">Using both positive and negative examples</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#           	<td></td>
#             <td> K = 1</td>
#             <td> K = 2</td>
#             <td> K = 3</td>
#             <td> K = 1</td>
#             <td> K = 2</td>
#             <td> K = 3</td>
#         </tr>
#       <tr>
#         <td>Precision</td>
#         <td>17.65%</td>
#         <td>14.25%</td>
#         <td>12.13%</td>
#           <td><b>18.39%</b></td>
#         <td>14.70%</td>
#         <td>12.43%</td>
#       </tr>
#       <tr>
#         <td>Recall</td>
#         <td>17.65%</td>
#         <td>28.50%</td>
#         <td>36.40%</td>
#         <td>18.39%</td>
#         <td>29.40%</td>
#           <td><b>37.30%</b></td>
#       </tr>
#       <tr>
#         <td>F1</td>
#         <td>17.65%</td>
#         <td>19.0%</td>
#         <td>18.20%</td>
#         <td>18.39%</td>
#           <td><b>19.60%</b></td>
#         <td>18.65%</td>
#       </tr>
#     </tbody>
# </table>

# %%
class Movies2Vec:
    def __init__(self):
        self.ratings = pd.read_csv('data_1m/ratings.csv', header=0)
        self.ratings['movieId'] = self.ratings['movieId'].astype(str)

    def create_and_evaluate(self):
        self.only_pos_scores = []
        self.pos_neg_scores = []
        self.k_values = [1, 2, 3]
        for i in range(len(self.k_values)):
            self.only_pos_scores.append({'precision':[], 'recall':[], 'f1':[]})
            self.pos_neg_scores.append({'precision':[], 'recall':[], 'f1':[]})

        # Use 5-Fold Cross-validation for model evaluation
        kf = KFold(n_splits=5, shuffle=True)
        iter = 1
        for train, test in kf.split(self.ratings):
            self.train_data = self.ratings.iloc[train]
            self.test_data = self.ratings.iloc[test]
            
            # Extract so-called "senteces" from plain list of reviews by grouping them by userId and separating them into liked and disliked
            # All movies liked by a particular user will build a sentence. The same applies to the list of movies disliked by a user
            self.train_sentences = self.get_sentences(self.train_data)

            self.create_model(iter)
            self.evaluate_model(iter)

            iter += 1
            
        # For an overall evaluation, the mean score of the 5 Folds is computed for each of the 3 evaluation metrics.    
        for i in range(len(self.k_values)):
            print("Mean scores (using only positive examples at testing) at K@{}".format(self.k_values[i]))
            print("Precision: {:.2%}".format(np.mean(self.only_pos_scores[i]['precision'])))
            print("Recall: {:.2%}".format(np.mean(self.only_pos_scores[i]['recall'])))
            print("F1: {:.2%}\n".format(np.mean(self.only_pos_scores[i]['f1'])))
            
            print("Mean scores (using both positive and negative examples at testing) at K@{}".format(self.k_values[i]))
            print("Precision: {:.2%}".format(np.mean(self.pos_neg_scores[i]['precision'])))
            print("Recall: {:.2%}".format(np.mean(self.pos_neg_scores[i]['recall'])))
            print("F1: {:.2%}\n".format(np.mean(self.pos_neg_scores[i]['f1'])))

    def get_sentences(self, ratings):
        # Mark as liked all ratings >= 3. 
        positive_ratings = ratings[ratings['rating'] >= 3]
        negative_ratings = ratings[ratings['rating'] < 3]
        
        # Group ratings by user id in order to extract list of movies the user liked or disliked. 
        # These lists will represent the so-called "senteces" used in training the Word2Vec model
        positive_ratings_by_user = positive_ratings.groupby(['userId'])
        negative_ratings_by_user = negative_ratings.groupby(['userId'])

        positive_sentences = [positive_ratings_by_user.get_group(positive_group)['movieId'].tolist() 
                 for positive_group in positive_ratings_by_user.groups]
        negative_sentences = [negative_ratings_by_user.get_group(negative_group)['movieId'].tolist() 
                 for negative_group in negative_ratings_by_user.groups]
        
        return (positive_sentences + negative_sentences)

    def create_model(self, iter):
        self.model = Word2Vec(self.train_sentences,
                              size=64,
                              window=999,
                              min_count=5,
                              workers=8,
                              iter=30,
                              sg=1,
                              hs=0,
                              sample=5e-4,
                              negative=30)

        # Save the model for each try
        model_name = "model_" + str(iter)
        self.model.save(model_name)

    def evaluate_model(self, iter):
        # In order to evaluate the model I need the lists of liked(1) and disliked(2) movies grouped by userId used in training 
        # and the list of liked movies from the test data(3). 
        # The model will try to predict the movies in the last set of lists (3) based on the first 2 sets of lists(1,2).
        liked_train = self.get_movies_list_by_user(self.train_data, is_liked=True)
        disliked_train = self.get_movies_list_by_user(self.train_data, is_liked=False)

        liked_test = self.get_movies_list_by_user(self.test_data, is_liked=True)

        self.get_scores(liked_train, disliked_train, liked_test, iter)

    def get_movies_list_by_user(self, data, is_liked):
        # Mark as liked all ratings >= 3. 
        positive_ratings = data[data['rating'] >= 3]
        negative_ratings = data[data['rating'] < 3]
        ratings = positive_ratings if is_liked else negative_ratings
        
        # Pick only the movies found in the model's vocabulary, since these are the only terms that can be used in prediction
        ratings = ratings[ratings['movieId'].isin(self.model.wv.vocab.keys())]

        movies_by_user = {k: list(v) for k, v in ratings.groupby('userId')['movieId']}

        return movies_by_user

    def get_scores(self, liked_train, disliked_train, liked_test, iter):
        # As explained before, I'll use two options when predicting
        # 1. one that only uses the user's liked movies list used in training
        # 2. another one that uses both user's liked and disliked movies list from the training set
        
        # The number of predictions will be proportional to the size of the test movies list 
        # I'll make 3 sets of predictions (based on the K values). Each prediction will recommend k * len(test_movies) where k = 1,2,3
        # The following 4 variables will be used for computing Precision, Recall and F1 score
        
        # Number of positive ratings from the test set
        total_liked = np.zeros(len(self.k_values))
        
        # Number of correctly predicted liked movies when option 1. was used for predicting
        total_correct = np.zeros(len(self.k_values))
        
        # Number of correctly predicted liked movies when option 2. was used for predicting
        total_correct_with_negative = np.zeros(len(self.k_values))
        
        # Total number of predictions
        total_no_of_predictions = np.zeros(len(self.k_values));
        
        # Select only the users who offered ratings in the training set
        common_users = set(liked_test.keys()).intersection(set(liked_train.keys()))

        # Iterate through these users and try to predict their unseen liked movies
        for user_id in common_users:
            # List the model will try to predict
            test_movies = liked_test[user_id]

            disliked_movies = []
            if user_id in disliked_train:
                disliked_movies = disliked_train[user_id]

            for i in range(len(self.k_values)):
                topn = self.k_values[i] * len(test_movies)
                # Option 1.
                predictions_with_pos = self.model.wv.most_similar_cosmul(positive=liked_train[user_id],
                                                                         topn=topn)
                # Option 2.
                predictions_with_pos_neg = self.model.wv.most_similar_cosmul(positive=liked_train[user_id],
                                                                              negative=disliked_movies,
                                                                              topn=topn)

                for predicted_movie, score in predictions_with_pos_neg:
                    if predicted_movie in test_movies:
                        total_correct_with_negative[i] += 1.0

                for predicted_movie, score in predictions_with_pos:
                    if predicted_movie in test_movies:
                        total_correct[i] += 1.0
                        
                total_liked[i] += len(test_movies)
                total_no_of_predictions[i] += topn

        
        # For each K value and prediction option compute the evaluation metrics:
        # Precision: ratio between the number of correctly made predictions and the total number of predictions. 
        #            It will decrease as K increases, since with higher values with K, more predictions are being made
        # Recall: ratio between the number of correctly made predictions and the actual number of liked movies in the test dataset
        #         It will increase as K increases, since the probability of predicting the correct movies increases when the number of predictions increases
        # F1: harmonic mean between the two
        for i in range(len(self.k_values)):
            self.only_pos_scores[i]['precision'].append(total_correct[i] / total_no_of_predictions[i])
            self.only_pos_scores[i]['recall'].append(total_correct[i] / total_liked[i])
            self.only_pos_scores[i]['f1'].append(2/((total_no_of_predictions[i] / total_correct[i]) + (total_liked[i] / total_correct[i])))
            
            self.pos_neg_scores[i]['precision'].append(total_correct_with_negative[i] / total_no_of_predictions[i])
            self.pos_neg_scores[i]['recall'].append(total_correct_with_negative[i] / total_liked[i])
            self.pos_neg_scores[i]['f1'].append(2/((total_no_of_predictions[i] / total_correct_with_negative[i]) + (total_liked[i] / total_correct_with_negative[i])))
            
            print("Scores (using only positive examples at prediction) at Fold {}, K @{}"
                  .format(iter, self.k_values[i]))
            print("Precision: {:.2%}; Recall: {:.2%}, F1: {:.2%}\n"
                  .format(self.only_pos_scores[i]['precision'][-1], self.only_pos_scores[i]['recall'][-1],
                         self.only_pos_scores[i]['f1'][-1]))
            
            print("Scores (using both positive and negative examples at prediction) at Fold {}, K @{}"
                  .format(iter, self.k_values[i]))
            print("Precision: {:.2%}; Recall: {:.2%}, F1: {:.2%}\n"
                  .format(self.pos_neg_scores[i]['precision'][-1], self.pos_neg_scores[i]['recall'][-1],
                         self.pos_neg_scores[i]['f1'][-1]))


model = Movies2Vec()
model.create_and_evaluate()
# Out:
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 762735 words, keeping 3666 word types
# INFO:gensim.models.word2vec:collected 3675 word types from a corpus of 800167 raw words and 11735 sentences
# INFO:gensim.models.word2vec:Loading a fresh vocabulary
# INFO:gensim.models.word2vec:effective_min_count=5 retains 3369 unique words (91% of original 3675, drops 306)
# INFO:gensim.models.word2vec:effective_min_count=5 leaves 799525 word corpus (99% of original 800167, drops 642)
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 3675 items
# INFO:gensim.models.word2vec:sample=0.0005 downsamples 107 most-common words
# INFO:gensim.models.word2vec:downsampling leaves estimated 768768 word corpus (96.2% of prior 799525)
# INFO:gensim.models.base_any2vec:estimated required memory for 3369 words and 64 dimensions: 3409428 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.models.base_any2vec:training model with 8 workers on 3369 vocabulary and 64 features, using sg=1 hs=0 sample=0.0005 negative=30 window=999
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 0.99% examples, 1260 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 1.87% examples, 2229 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 3.58% examples, 3948 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 4.27% examples, 4435 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 6.50% examples, 6059 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 7.29% examples, 5017 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 8.11% examples, 5017 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 8.86% examples, 5194 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 10.17% examples, 5568 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 12.33% examples, 6423 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 13.16% examples, 5769 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 13.90% examples, 5764 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 14.77% examples, 5568 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 15.36% examples, 5544 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 16.63% examples, 5896 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 17.83% examples, 6026 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 19.34% examples, 6327 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 20.46% examples, 6288 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 21.35% examples, 6194 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 22.39% examples, 6255 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 24.13% examples, 6313 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 25.88% examples, 6242 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 27.26% examples, 6370 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 28.04% examples, 6300 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 28.79% examples, 6344 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 30.21% examples, 6341 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 31.50% examples, 6353 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 32.10% examples, 6199 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 34.24% examples, 6525 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 34.95% examples, 6497 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 35.51% examples, 6392 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 36.28% examples, 6260 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 37.11% examples, 6252 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 37.78% examples, 6276 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 38.46% examples, 6279 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 40.76% examples, 6514 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 41.51% examples, 6508 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 42.28% examples, 6482 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 43.27% examples, 6385 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 44.77% examples, 6421 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 47.05% examples, 6620 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 47.82% examples, 6627 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 51.79% examples, 6527 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 52.43% examples, 6550 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 57.77% examples, 6638 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 70.29% examples, 6967 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 75.24% examples, 7074 words/s, in_qsize 7, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 78.31% examples, 7076 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 82.56% examples, 7081 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 100.00% examples, 7442 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 1 : training on 800167 raw words (768950 effective words) took 103.3s, 7442 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 0.99% examples, 1061 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 2.75% examples, 2902 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 4.27% examples, 4015 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 6.50% examples, 5219 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 7.29% examples, 4421 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 8.11% examples, 4546 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 9.54% examples, 5162 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 10.17% examples, 5247 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 11.65% examples, 5640 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 13.16% examples, 5239 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 13.90% examples, 5236 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 14.77% examples, 5328 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 15.36% examples, 5216 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 16.63% examples, 5501 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 17.83% examples, 5609 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 19.34% examples, 5872 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 21.35% examples, 5866 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 22.39% examples, 5903 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 24.13% examples, 5964 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 25.88% examples, 6098 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 26.56% examples, 5972 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 27.26% examples, 6036 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 28.04% examples, 6040 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 28.79% examples, 6089 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 29.50% examples, 6100 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 30.21% examples, 6007 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 30.81% examples, 6009 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 31.50% examples, 5964 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 32.89% examples, 6056 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 34.24% examples, 6197 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 34.95% examples, 6191 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 35.51% examples, 6047 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 36.28% examples, 5900 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 37.11% examples, 5925 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 37.78% examples, 5961 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 39.88% examples, 6176 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 40.76% examples, 6214 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 41.51% examples, 6183 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 42.28% examples, 6138 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 44.05% examples, 6188 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 44.77% examples, 6164 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 45.50% examples, 6189 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 47.82% examples, 6338 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 48.60% examples, 6283 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 56.28% examples, 6360 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 57.77% examples, 6389 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 70.29% examples, 6702 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 75.05% examples, 6796 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 82.41% examples, 6824 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 96.31% examples, 7117 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 2 : training on 800167 raw words (768551 effective words) took 106.9s, 7187 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 0.99% examples, 1050 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 3.58% examples, 3372 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 4.27% examples, 3844 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 6.50% examples, 5231 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 7.29% examples, 4334 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 8.11% examples, 4514 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 9.54% examples, 4869 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 10.17% examples, 5002 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 12.33% examples, 5687 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 13.16% examples, 5145 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 14.77% examples, 5143 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 15.36% examples, 5067 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 17.19% examples, 5604 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 17.83% examples, 5652 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 18.60% examples, 5643 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 20.46% examples, 5862 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 21.35% examples, 5706 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 23.38% examples, 5878 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 24.13% examples, 5868 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 24.99% examples, 5919 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 25.88% examples, 5872 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 26.56% examples, 5933 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 27.26% examples, 5999 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 28.04% examples, 5886 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 29.50% examples, 6060 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 30.21% examples, 5925 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 30.81% examples, 5970 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 31.50% examples, 5946 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 32.10% examples, 5826 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 34.95% examples, 6087 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 35.51% examples, 6049 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 36.28% examples, 5841 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 37.11% examples, 5874 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 37.78% examples, 5876 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 38.46% examples, 5919 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 39.88% examples, 6079 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 40.76% examples, 6120 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 41.51% examples, 6147 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 42.28% examples, 6075 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 43.27% examples, 6044 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 44.77% examples, 6057 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 46.31% examples, 6164 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 51.79% examples, 6155 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 53.21% examples, 6264 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 59.62% examples, 6320 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 67.06% examples, 6529 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 75.05% examples, 6705 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 78.31% examples, 6687 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 81.41% examples, 6702 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 100.00% examples, 7074 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 3 : training on 800167 raw words (768811 effective words) took 108.7s, 7074 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 0.99% examples, 1100 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 1.87% examples, 1935 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 4.27% examples, 3902 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 6.50% examples, 5404 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 7.29% examples, 4471 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 8.11% examples, 4434 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 9.54% examples, 4997 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 10.20% examples, 5111 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 13.16% examples, 5168 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 13.90% examples, 5157 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 14.77% examples, 5143 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 15.42% examples, 5065 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 17.19% examples, 5641 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 17.83% examples, 5582 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 18.57% examples, 5668 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 19.34% examples, 5653 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 21.35% examples, 5675 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 23.38% examples, 5860 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 24.13% examples, 5857 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 24.99% examples, 5913 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 25.88% examples, 5858 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 26.56% examples, 5864 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 27.26% examples, 5812 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 28.01% examples, 5854 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 29.50% examples, 5954 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 30.21% examples, 5918 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 31.50% examples, 5821 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 32.10% examples, 5863 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 33.63% examples, 6038 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 34.24% examples, 5973 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 35.51% examples, 5883 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 36.28% examples, 5830 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 37.11% examples, 5732 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 39.88% examples, 6100 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 40.76% examples, 6126 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 41.51% examples, 6000 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 43.27% examples, 5997 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 44.05% examples, 5968 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 44.77% examples, 5992 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 47.05% examples, 6215 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 47.82% examples, 6157 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 51.79% examples, 6103 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 53.21% examples, 6205 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 57.77% examples, 6241 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 67.06% examples, 6459 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 75.05% examples, 6616 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 78.31% examples, 6650 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 82.41% examples, 6634 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 4 : training on 800167 raw words (769061 effective words) took 109.4s, 7030 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 0.99% examples, 1069 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 2.75% examples, 2817 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 4.40% examples, 3917 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 6.50% examples, 5170 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 7.29% examples, 4444 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 8.11% examples, 4448 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 9.54% examples, 4872 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 10.20% examples, 5022 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 12.33% examples, 5897 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 13.16% examples, 5157 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 14.77% examples, 5062 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 15.36% examples, 5052 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 17.19% examples, 5623 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 17.83% examples, 5453 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 20.46% examples, 5692 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 21.49% examples, 5690 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 23.38% examples, 5879 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 24.13% examples, 5861 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 24.99% examples, 5816 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 25.88% examples, 5694 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 26.58% examples, 5753 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 28.04% examples, 5835 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 29.50% examples, 5977 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 30.11% examples, 5818 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 31.50% examples, 5801 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 32.23% examples, 5797 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 34.24% examples, 6039 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 34.95% examples, 5963 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 35.51% examples, 5914 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 36.28% examples, 5748 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 37.78% examples, 5779 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 39.22% examples, 5932 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 40.76% examples, 6018 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 41.51% examples, 6029 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 42.28% examples, 5948 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 43.27% examples, 5953 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 44.77% examples, 5964 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 46.32% examples, 6059 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 47.82% examples, 6159 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 51.79% examples, 6029 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 56.28% examples, 6122 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 58.34% examples, 6181 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 62.57% examples, 6383 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 75.05% examples, 6568 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 78.31% examples, 6582 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 82.41% examples, 6582 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 100.00% examples, 6948 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 5 : training on 800167 raw words (768925 effective words) took 110.7s, 6948 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 0.99% examples, 1061 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 1.87% examples, 1892 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 3.58% examples, 3308 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 4.27% examples, 3657 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 6.50% examples, 5018 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 7.29% examples, 4359 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 8.11% examples, 4441 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 8.86% examples, 4541 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 10.17% examples, 4835 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 12.33% examples, 5688 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 13.16% examples, 5078 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 13.90% examples, 5188 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 14.77% examples, 4797 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 15.93% examples, 5042 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 17.93% examples, 5425 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 19.34% examples, 5737 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 20.46% examples, 5453 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 22.39% examples, 5637 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 23.38% examples, 5594 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 24.99% examples, 5749 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 25.67% examples, 5561 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 26.56% examples, 5625 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 28.04% examples, 5709 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 29.50% examples, 5718 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 30.21% examples, 5696 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 31.50% examples, 5666 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 32.23% examples, 5655 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 34.24% examples, 5947 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 34.95% examples, 5848 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 35.51% examples, 5675 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 36.28% examples, 5648 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 37.78% examples, 5659 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 39.88% examples, 5895 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 40.76% examples, 5914 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 41.51% examples, 5800 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 43.27% examples, 5874 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 44.77% examples, 5842 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 46.32% examples, 5965 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 47.82% examples, 5967 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 48.60% examples, 5939 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 53.21% examples, 6059 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 58.34% examples, 6068 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 67.76% examples, 6354 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 78.31% examples, 6525 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 82.56% examples, 6493 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 93.22% examples, 6696 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 6 : training on 800167 raw words (768745 effective words) took 112.1s, 6856 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 0.99% examples, 1070 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 2.75% examples, 2779 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 4.40% examples, 3715 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 6.50% examples, 5199 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 7.29% examples, 4323 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 8.11% examples, 4412 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 8.86% examples, 4547 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 10.35% examples, 4872 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 12.33% examples, 5738 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 13.16% examples, 5008 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 13.90% examples, 5107 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 14.77% examples, 4972 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 15.36% examples, 4964 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 16.63% examples, 5282 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 17.83% examples, 5363 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 19.34% examples, 5671 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 20.46% examples, 5654 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 21.35% examples, 5577 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 23.38% examples, 5748 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 24.13% examples, 5786 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 24.99% examples, 5711 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 25.88% examples, 5640 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 26.56% examples, 5650 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 28.04% examples, 5688 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 29.50% examples, 5821 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 30.11% examples, 5676 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 31.50% examples, 5708 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 32.23% examples, 5642 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 34.24% examples, 5933 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 34.95% examples, 5837 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 35.51% examples, 5801 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 36.28% examples, 5675 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 37.11% examples, 5661 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 37.78% examples, 5652 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 39.88% examples, 5877 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 40.76% examples, 5884 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 42.28% examples, 5886 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 43.27% examples, 5839 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 44.77% examples, 5812 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 46.32% examples, 5930 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 51.79% examples, 5902 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 56.92% examples, 6108 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 59.62% examples, 6103 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 60.46% examples, 6124 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 70.98% examples, 6403 words/s, in_qsize 9, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 78.31% examples, 6462 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 81.41% examples, 6455 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 7 : training on 800167 raw words (768850 effective words) took 112.6s, 6830 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 0.99% examples, 1020 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 1.87% examples, 1842 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 4.27% examples, 3800 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 6.50% examples, 5037 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 7.29% examples, 4222 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 8.11% examples, 4314 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 8.86% examples, 4538 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 10.17% examples, 4963 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 10.98% examples, 5081 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 13.16% examples, 4934 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 13.90% examples, 4979 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 14.77% examples, 5028 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 15.36% examples, 4908 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 16.63% examples, 5180 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 17.83% examples, 5254 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 19.34% examples, 5528 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 21.35% examples, 5497 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 22.39% examples, 5551 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 23.38% examples, 5587 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 24.13% examples, 5646 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 24.99% examples, 5596 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 25.88% examples, 5619 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 26.56% examples, 5569 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 27.26% examples, 5615 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 28.04% examples, 5655 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 28.79% examples, 5702 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 29.50% examples, 5683 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 30.21% examples, 5534 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 31.50% examples, 5594 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 32.10% examples, 5596 words/s, in_qsize 15, out_qsize 0
# ...
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 28 : training on 800168 raw words (768883 effective words) took 151.1s, 5088 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 1.00% examples, 794 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 1.87% examples, 1433 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 3.59% examples, 2542 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 4.40% examples, 2862 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 5.78% examples, 3700 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 6.50% examples, 3836 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 7.30% examples, 3220 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 8.11% examples, 3192 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 8.85% examples, 3301 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 10.16% examples, 3584 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 12.33% examples, 4138 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 13.14% examples, 3653 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 13.89% examples, 3693 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 14.76% examples, 3632 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 15.41% examples, 3602 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 17.17% examples, 3937 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 17.81% examples, 3878 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 18.57% examples, 3953 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 20.39% examples, 4186 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 21.42% examples, 4100 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 23.36% examples, 4193 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 24.12% examples, 4203 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 24.98% examples, 4141 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 25.88% examples, 4209 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 26.54% examples, 4112 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 28.03% examples, 4200 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 29.50% examples, 4276 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 30.09% examples, 4170 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 31.47% examples, 4119 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 33.59% examples, 4296 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 34.21% examples, 4312 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 34.91% examples, 4276 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 35.49% examples, 4215 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 36.28% examples, 4087 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 37.78% examples, 4180 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 38.42% examples, 4211 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 39.86% examples, 4311 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 40.74% examples, 4331 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 41.47% examples, 4297 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 42.26% examples, 4270 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 43.26% examples, 4306 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 44.04% examples, 4342 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 44.75% examples, 4312 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 45.55% examples, 4322 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 47.80% examples, 4428 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 51.75% examples, 4383 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 56.22% examples, 4457 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 57.70% examples, 4491 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 60.38% examples, 4526 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 70.84% examples, 4747 words/s, in_qsize 9, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 78.15% examples, 4817 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 82.31% examples, 4794 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 96.28% examples, 5011 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 29 : training on 800168 raw words (768758 effective words) took 151.7s, 5068 effective words/s
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 1.00% examples, 833 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 1.87% examples, 1471 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 2.73% examples, 2018 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 4.40% examples, 2855 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 6.50% examples, 3836 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 7.30% examples, 3310 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 8.11% examples, 3283 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 8.85% examples, 3352 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 9.53% examples, 3480 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 10.20% examples, 3590 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 12.33% examples, 4208 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 13.14% examples, 3753 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 13.89% examples, 3726 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 14.76% examples, 3633 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 15.41% examples, 3612 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 16.01% examples, 3706 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 17.17% examples, 3983 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 17.81% examples, 3895 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 19.28% examples, 4136 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 20.39% examples, 4175 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 21.34% examples, 4075 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 23.36% examples, 4191 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 24.12% examples, 4218 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 24.98% examples, 4197 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 25.88% examples, 4203 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 26.54% examples, 4148 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 27.23% examples, 4215 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 27.97% examples, 4210 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 29.50% examples, 4312 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 30.09% examples, 4201 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 31.47% examples, 4169 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 32.09% examples, 4197 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 33.59% examples, 4306 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 34.21% examples, 4328 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 34.91% examples, 4304 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 35.49% examples, 4240 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 36.28% examples, 4129 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 37.10% examples, 4141 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 37.78% examples, 4179 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 38.42% examples, 4215 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 40.74% examples, 4350 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 41.47% examples, 4321 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 42.26% examples, 4308 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 43.26% examples, 4318 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 44.04% examples, 4330 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 44.75% examples, 4303 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 46.30% examples, 4374 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 47.80% examples, 4453 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 48.58% examples, 4383 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 53.17% examples, 4461 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 58.26% examples, 4485 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 70.14% examples, 4709 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 74.97% examples, 4794 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 78.15% examples, 4822 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 82.44% examples, 4799 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 96.28% examples, 5023 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 30 : training on 800168 raw words (769152 effective words) took 151.5s, 5076 effective words/s
# INFO:gensim.models.base_any2vec:training on a 24005040 raw words (23070697 effective words) took 4093.0s, 5637 effective words/s
# INFO:gensim.utils:saving Word2Vec object under model_5, separately None
# INFO:gensim.utils:not storing attribute vectors_norm
# INFO:gensim.utils:not storing attribute cum_table
# INFO:gensim.utils:saved model_5
# INFO:gensim.models.keyedvectors:precomputing L2-norms of word weight vectors
# Scores (using only positive examples at prediction) at Fold 5, K @1
# Precision: 17.66%; Recall: 17.66%, F1: 17.66%
#
# Scores (using both positive and negative examples at prediction) at Fold 5, K @1
# Precision: 18.39%; Recall: 18.39%, F1: 18.39%
#
# Scores (using only positive examples at prediction) at Fold 5, K @2
# Precision: 14.21%; Recall: 28.42%, F1: 18.95%
#
# Scores (using both positive and negative examples at prediction) at Fold 5, K @2
# Precision: 14.69%; Recall: 29.38%, F1: 19.58%
#
# Scores (using only positive examples at prediction) at Fold 5, K @3
# Precision: 12.07%; Recall: 36.20%, F1: 18.10%
#
# Scores (using both positive and negative examples at prediction) at Fold 5, K @3
# Precision: 12.39%; Recall: 37.16%, F1: 18.58%
#
# Mean scores (using only positive examples at testing) at K@1
# Precision: 17.65%
# Recall: 17.65%
# F1: 17.65%
#
# Mean scores (using both positive and negative examples at testing) at K@1
# Precision: 18.39%
# Recall: 18.39%
# F1: 18.39%
#
# Mean scores (using only positive examples at testing) at K@2
# Precision: 14.25%
# Recall: 28.50%
# F1: 19.00%
#
# Mean scores (using both positive and negative examples at testing) at K@2
# Precision: 14.70%
# Recall: 29.40%
# F1: 19.60%
#
# Mean scores (using only positive examples at testing) at K@3
# Precision: 12.13%
# Recall: 36.40%
# F1: 18.20%
#
# Mean scores (using both positive and negative examples at testing) at K@3
# Precision: 12.43%
# Recall: 37.30%
# F1: 18.65%

# %% [markdown]
# ## References
# \[1\] Barkan, O., & Koenigstein, N. (2016). [ITEM2VEC: Neural item embedding for collaborative filtering](https://arxiv.org/abs/1603.04259). 2016 IEEE 26th International Workshop on Machine Learning for Signal Processing (MLSP), 1-6.
#
# \[2\] Hugo Caselles-Dupre, Florian Lesaint, and Jimena Royo-Letelier. [Word2vec applied to recommendation: Hyperparameters matter](https://arxiv.org/abs/1804.04212). CoRR, abs/1804.04212, 2018.
#
# \[3\] Makbule Gulcin Ozsoy. 2016. [From word embeddings to item recommendation](https://arxiv.org/abs/1601.01356). arXiv preprint arXiv:1601.01356 (2016).
#
# \[4\] http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
#
# \[5\] Tomas Mikolov, Ilya Sutskever, Kai Chen, Greg Corrado, and Jeffrey Dean. 2013b. [Distributed representations of words and phrases and their compositionality](https://arxiv.org/abs/1310.4546). In NIPS, pages 3111–3119.
#
# \[6\] [Movielens 1M dataset](https://grouplens.org/datasets/movielens/1m/)
